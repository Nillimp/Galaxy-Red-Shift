# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# %%
file_path = 'SDSS_DR18_GALAXY.csv'
data = pd.read_csv(file_path)
data.head()
# Out:
#           objid     specobjid          ra       dec         u         g  \
# 0  1.240000e+18  8.180000e+18   82.038679  0.847177  21.73818  20.26633
# 1  1.240000e+18  8.180000e+18   82.138894  1.063072  20.66761  19.32016
# 2  1.240000e+18  8.180000e+18   82.028510  1.104003  23.63531  21.19671
# 3  1.240000e+18  3.320000e+17  198.544469 -1.097059  20.12374  18.41520
# 4  1.240000e+18  3.320000e+17  198.720675 -1.083876  19.47473  18.18575
#
#           r         i         z  modelFlux_u  ...  psfMag_z   expAB_u  \
# 0  19.32409  18.64037  18.23833     2.007378  ...  19.43575  0.099951
# 1  18.67888  18.24693  18.04122     5.403369  ...  18.85012  0.366549
# 2  19.92297  19.31443  18.68396     0.295693  ...  19.42235  0.050000
# 3  17.47202  17.05297  16.72423     8.920645  ...  18.03204  0.310763
# 4  17.52763  17.14837  16.89580    16.220930  ...  18.23220  0.754158
#
#     expAB_g   expAB_r   expAB_i   expAB_z   class     subclass  redshift  \
# ...

# %%
X = data[['u', 'g', 'r', 'i', 'z']]
y = data['redshift']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=3)  
X_pca = pca.fit_transform(X_scaled)

# %%
X_train_pca, X_test_pca, y_train, y_test = train_test_split(X_pca, y, test_size=0.3, random_state=42)

# %%
model_enet = ElasticNet(alpha=1.0, l1_ratio=0.5, random_state=42)

model_enet.fit(X_train_pca, y_train)
# Out:
# ElasticNet(random_state=42)

# %%
y_pred_pca = model_enet.predict(X_test_pca)

# %%
rmse_enet_pca = mean_squared_error(y_test, y_pred_pca, squared=False)  
r2_enet_pca = r2_score(y_test, y_pred_pca)

print("RMSE (Elastic Net with PCA):", rmse_enet_pca)
print("R-squared (Elastic Net with PCA):", r2_enet_pca)
# Out:
# RMSE (Elastic Net with PCA): 0.10031290445806958
# R-squared (Elastic Net with PCA): -2.2721830468253046e-06
# c:\Users\klair\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
