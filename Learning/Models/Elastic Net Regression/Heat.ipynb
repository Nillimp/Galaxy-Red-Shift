# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('SDSS_DR18_filtered.csv')
data.head()
# Out:
#           objid     specobjid          ra       dec         u         g  \
# 0  1.240000e+18  3.240000e+17  184.950869  0.733068  18.87062  17.59612
# 1  1.240000e+18  3.240000e+17  185.687690  0.823480  19.26421  17.87891
# 2  1.240000e+18  3.240000e+17  185.677759  0.698527  18.73206  17.52809
# 3  1.240000e+18  3.240000e+17  185.601630  0.715945  18.37217  16.48591
# 4  1.240000e+18  3.240000e+17  185.140667  0.788058  15.96589  15.01389
#
#           r         i         z  run  ...  psfMag_g  psfMag_i  psfMag_z  \
# 0  17.11245  16.83899  16.70908  756  ...  19.96352  19.25145  19.05230
# 1  17.09593  16.65159  16.35329  756  ...  19.33645  18.16669  17.78844
# 2  16.91648  16.54232  16.32265  756  ...  18.48901  17.60799  17.37348
# 3  15.64821  15.25808  14.94688  756  ...  17.64998  16.47852  16.16574
# 4  14.40374  14.18948  14.14311  756  ...  19.78541  19.00860  18.77316
#
#     expAB_u   expAB_g   expAB_r   expAB_i   expAB_z  redshift   class
# 0  0.479021  0.518483  0.520474  0.508502  0.488969  0.041691  GALAXY
# 1  0.701666  0.743386  0.770897  0.778642  0.736771  0.113069  GALAXY
# 2  0.963002  0.966176  0.924923  0.890450  0.921945  0.062959  GALAXY
# 3  0.666844  0.618301  0.581590  0.575267  0.588856  0.041979  GALAXY
# 4  0.348750  0.349994  0.349913  0.350000  0.349999  0.007078  GALAXY
#
# [5 rows x 43 columns]

# %%
bands = ['u', 'g', 'r', 'i', 'z']

# %%
corr_matrix = data[bands].corr()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Heatmap of Photometric Bands - Multicollinearity Check')
plt.show()
